# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch import Tensor
from collections import OrderedDict
from torch.utils.data import DataLoader, Dataset

# %%
training_epochs = 100
learning_rate = 1e-3
batch_size = 32

# %%
filename = 'splitted_dataset.npz'
dataset = np.load(filename)

# %%
inputs_train = dataset['inputs_train']
inputs_test  = dataset['inputs_test']
inputs_valid = dataset['inputs_valid']
labels_train = dataset['labels_train']
labels_test  = dataset['labels_test']
labels_valid = dataset['labels_valid']

# %%
class Custom_dataset(Dataset):
    
    def __init__(self, inputs, labels):
        self.inputs = torch.from_numpy(inputs).float()
        self.labels = torch.from_numpy(labels).long()
    
    def __len__(self):
        return len(self.inputs)
    
    def __getitem__(self, index):
        inputs = self.inputs[index]
        labels = self.labels[index]
        return inputs, labels

# %%
train_set = Custom_dataset(inputs = inputs_train,
                           labels = labels_train)
test_set  = Custom_dataset(inputs = inputs_test,
                           labels = labels_test)
valid_set = Custom_dataset(inputs = inputs_valid,
                           labels = labels_valid)

# %%
train_loader = DataLoader(dataset=train_set,
                          batch_size=batch_size,
                          shuffle=True,
                          drop_last=True)
test_loader  = DataLoader(dataset=test_set,
                          batch_size=batch_size,
                          shuffle=True,
                          drop_last=False)
valid_loader = DataLoader(dataset=valid_set,
                          batch_size=batch_size,
                          shuffle=True,
                          drop_last=False)

# %%
class _DenseLayer(nn.Module):
    def __init__(self, num_input_features, growth_rate, bn_size, drop_rate, memory_efficient=False):
        super(_DenseLayer, self).__init__()
        self.add_module('norm1', nn.BatchNorm2d(num_input_features)),
        self.add_module('relu1', nn.ReLU(inplace=True)),
        self.add_module('conv1', nn.Conv2d(num_input_features, bn_size *
                                           growth_rate, kernel_size=1, stride=1,
                                           bias=False)),
        self.add_module('norm2', nn.BatchNorm2d(bn_size * growth_rate)),
        self.add_module('relu2', nn.ReLU(inplace=True)),
        self.add_module('conv2', nn.Conv2d(bn_size * growth_rate, growth_rate,
                                           kernel_size=3, stride=1, padding=1,
                                           bias=False)),
        self.drop_rate = float(drop_rate)
        self.memory_efficient = memory_efficient

    def bn_function(self, inputs):
        # type: (List[Tensor]) -> Tensor
        concated_features = torch.cat(inputs, 1)
        bottleneck_output = self.conv1(self.relu1(self.norm1(concated_features)))  # noqa: T484
        return bottleneck_output

    # todo: rewrite when torchscript supports any
    def any_requires_grad(self, input):
        # type: (List[Tensor]) -> bool
        for tensor in input:
            if tensor.requires_grad:
                return True
        return False


    # torchscript does not yet support *args, so we overload method
    # allowing it to take either a List[Tensor] or single Tensor
    def forward(self, input):  # noqa: F811
        if isinstance(input, Tensor):
            prev_features = [input]
        else:
            prev_features = input

        if self.memory_efficient and self.any_requires_grad(prev_features):
            if torch.jit.is_scripting():
                raise Exception("Memory Efficient not supported in JIT")

            bottleneck_output = self.call_checkpoint_bottleneck(prev_features)
        else:
            bottleneck_output = self.bn_function(prev_features)

        new_features = self.conv2(self.relu2(self.norm2(bottleneck_output)))
        if self.drop_rate > 0:
            new_features = F.dropout(new_features, p=self.drop_rate,
                                     training=self.training)
        return new_features

# %%
class _DenseBlock(nn.ModuleDict):
    _version = 2

    def __init__(self, num_layers, num_input_features, bn_size, growth_rate, drop_rate, memory_efficient=False):
        super(_DenseBlock, self).__init__()
        for i in range(num_layers):
            layer = _DenseLayer(
                num_input_features + i * growth_rate,
                growth_rate=growth_rate,
                bn_size=bn_size,
                drop_rate=drop_rate,
                memory_efficient=memory_efficient,
            )
            self.add_module('denselayer%d' % (i + 1), layer)

    def forward(self, init_features):
        features = [init_features]
        for name, layer in self.items():
            new_features = layer(features)
            features.append(new_features)
        return torch.cat(features, 1)

# %%
class _Transition(nn.Sequential):
    def __init__(self, num_input_features, num_output_features):
        super(_Transition, self).__init__()
        self.add_module('norm', nn.BatchNorm2d(num_input_features))
        self.add_module('relu', nn.ReLU(inplace=True))
        self.add_module('conv', nn.Conv2d(num_input_features, num_output_features,
                                          kernel_size=1, stride=1, bias=False))
        self.add_module('pool', nn.AvgPool2d(kernel_size=2, stride=2))

# %%
class DenseNet(nn.Module):
    r"""Densenet-BC model class, based on
    `"Densely Connected Convolutional Networks" <https://arxiv.org/pdf/1608.06993.pdf>`_
    Args:
        growth_rate (int) - how many filters to add each layer (`k` in paper)
        block_config (list of 4 ints) - how many layers in each pooling block
        num_init_features (int) - the number of filters to learn in the first convolution layer
        bn_size (int) - multiplicative factor for number of bottle neck layers
          (i.e. bn_size * k features in the bottleneck layer)
        drop_rate (float) - dropout rate after each dense layer
        num_classes (int) - number of classification classes
        memory_efficient (bool) - If True, uses checkpointing. Much more memory efficient,
          but slower. Default: *False*. See `"paper" <https://arxiv.org/pdf/1707.06990.pdf>`_
    """

    def __init__(self, growth_rate=32, block_config=(6, 12, 24, 16),
                 num_init_features=64, bn_size=4, drop_rate=0.2, num_classes=11, memory_efficient=False):

        super(DenseNet, self).__init__()

        # First convolution
        self.features = nn.Sequential(OrderedDict([
            ('conv0', nn.Conv2d(4, num_init_features, kernel_size=7, stride=2,
                                padding=3, bias=False)),
            ('norm0', nn.BatchNorm2d(num_init_features)),
            ('relu0', nn.ReLU(inplace=True)),
            ('pool0', nn.MaxPool2d(kernel_size=3, stride=2, padding=1)),
        ]))

        # Each denseblock
        num_features = num_init_features
        for i, num_layers in enumerate(block_config):
            block = _DenseBlock(
                num_layers=num_layers,
                num_input_features=num_features,
                bn_size=bn_size,
                growth_rate=growth_rate,
                drop_rate=drop_rate,
                memory_efficient=memory_efficient
            )
            self.features.add_module('denseblock%d' % (i + 1), block)
            num_features = num_features + num_layers * growth_rate
            if i != len(block_config) - 1:
                trans = _Transition(num_input_features=num_features,
                                    num_output_features=num_features // 2)
                self.features.add_module('transition%d' % (i + 1), trans)
                num_features = num_features // 2

        # Final batch norm
        self.features.add_module('norm5', nn.BatchNorm2d(num_features))

        # Linear layer
        self.classifier = nn.Linear(num_features, num_classes)

        # Official init from torch repo.
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight)
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear):
                nn.init.constant_(m.bias, 0)

    def forward(self, x):
        features = self.features(x)
        out = F.relu(features, inplace=True)
        out = F.adaptive_avg_pool2d(out, (1, 1))
        out = torch.flatten(out, 1)
        out = self.classifier(out)
        return out
    
def _densenet(arch, growth_rate, block_config, num_init_features, pretrained, progress, **kwargs):
    return DenseNet(growth_rate, block_config, num_init_features, **kwargs)



def densenet_custom(pretrained=False, progress=True, **kwargs):
    return _densenet('densenet_custom', 20, (5, 5, 5), 32, pretrained, progress, **kwargs)

# %%
GPU_NUM = 7
device = torch.device(f'cuda:{GPU_NUM}' if torch.cuda.is_available() else 'cpu')
torch.cuda.set_device(device)
print('Currernt cuda device ', torch.cuda.current_device())

if device.type == 'cuda':
    print(torch.cuda.get_device_name(GPU_NUM))
    print('Memory Usage:')
    print('Allocated:', round(torch.cuda.memory_allocated(GPU_NUM)/1024**3,1), 'GB')
    print('Cached:   ', round(torch.cuda.memory_cached(GPU_NUM)/1024**3,1), 'GB')
# Out:
# Currernt cuda device  7
# GeForce RTX 2080 Ti
# Memory Usage:
# Allocated: 0.0 GB
# Cached:    0.0 GB

# %%
net = DenseNet().to(device)

# %%
criterion = nn.CrossEntropyLoss().to(device)
optimizer = torch.optim.SGD(net.parameters(), lr = 0.1, momentum = 0.9, weight_decay=5e-4)
lr_sche = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.5)

# %%
def acc_check(Net, dataset, epoch):
    correct = 0
    total = 0
    with torch.no_grad():
        for inputs, labels in dataset:
            
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            outputs = Net(inputs)
            
            _, predicted = torch.max(outputs.data, 1)
            
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        acc = (100 * correct / total)
        return acc

# %%
total_batch = len(train_loader)


for epoch in range(training_epochs):
    avg_cost = 0

    for i, (inputs, labels) in enumerate(train_loader):
        inputs = inputs.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()
        hypothesis = net(inputs)
        cost = criterion(hypothesis, labels)
        cost.backward()
        optimizer.step()

        avg_cost += cost / total_batch
    
    lr_sche.step()
    
    test_acc  = acc_check(net, test_loader, epoch)
    train_acc = acc_check(net, train_loader, epoch)
    print('[Epoch : {:>4}]'.format(epoch + 1, avg_cost))
    print('cost = {:>.7} \t Acc_Test  : {:>.3} \t Acc_Train : {:>.3}'.format(avg_cost, test_acc, train_acc))
print('Learning finished')
# Out:
# [Epoch :    1]
# cost = 2.964225 	 Acc_Test  : 8.0 	 Acc_Train : 10.2
# [Epoch :    2]
# cost = 2.73912 	 Acc_Test  : 12.0 	 Acc_Train : 10.6
# [Epoch :    3]
# cost = 2.463805 	 Acc_Test  : 10.0 	 Acc_Train : 11.4
# [Epoch :    4]
# cost = 2.379157 	 Acc_Test  : 12.0 	 Acc_Train : 14.8
# [Epoch :    5]
# cost = 2.284065 	 Acc_Test  : 19.5 	 Acc_Train : 22.1
# [Epoch :    6]
# cost = 2.141595 	 Acc_Test  : 25.0 	 Acc_Train : 26.5
# [Epoch :    7]
# cost = 1.994091 	 Acc_Test  : 29.0 	 Acc_Train : 24.2
# [Epoch :    8]
# cost = 1.917892 	 Acc_Test  : 24.0 	 Acc_Train : 23.9
# [Epoch :    9]
# cost = 1.87266 	 Acc_Test  : 28.5 	 Acc_Train : 31.6
# [Epoch :   10]
# cost = 1.812623 	 Acc_Test  : 24.0 	 Acc_Train : 30.6
# [Epoch :   11]
# cost = 1.609895 	 Acc_Test  : 31.0 	 Acc_Train : 32.5
# [Epoch :   12]
# cost = 1.58447 	 Acc_Test  : 31.5 	 Acc_Train : 31.8
# [Epoch :   13]
# cost = 1.530719 	 Acc_Test  : 35.5 	 Acc_Train : 38.8
# [Epoch :   14]
# cost = 1.430322 	 Acc_Test  : 36.0 	 Acc_Train : 41.2
# [Epoch :   15]
# cost = 1.39594 	 Acc_Test  : 41.0 	 Acc_Train : 46.4
# [Epoch :   16]
# cost = 1.312535 	 Acc_Test  : 43.0 	 Acc_Train : 48.6
# [Epoch :   17]
# cost = 1.301567 	 Acc_Test  : 41.0 	 Acc_Train : 46.9
# [Epoch :   18]
# cost = 1.202914 	 Acc_Test  : 40.5 	 Acc_Train : 46.1
# [Epoch :   19]
# cost = 1.175533 	 Acc_Test  : 42.5 	 Acc_Train : 49.4
# [Epoch :   20]
# cost = 1.29131 	 Acc_Test  : 47.0 	 Acc_Train : 54.0
# [Epoch :   21]
# cost = 1.125934 	 Acc_Test  : 46.0 	 Acc_Train : 54.5
# [Epoch :   22]
# cost = 1.069178 	 Acc_Test  : 45.5 	 Acc_Train : 59.0
# [Epoch :   23]
# cost = 1.002139 	 Acc_Test  : 48.0 	 Acc_Train : 65.5
# [Epoch :   24]
# cost = 0.9388785 	 Acc_Test  : 50.5 	 Acc_Train : 61.2
# [Epoch :   25]
# cost = 0.9634214 	 Acc_Test  : 42.0 	 Acc_Train : 57.8
# [Epoch :   26]
# cost = 0.9297687 	 Acc_Test  : 46.0 	 Acc_Train : 62.2
# [Epoch :   27]
# cost = 0.8662502 	 Acc_Test  : 49.0 	 Acc_Train : 65.2
# [Epoch :   28]
# cost = 0.8730068 	 Acc_Test  : 55.0 	 Acc_Train : 66.9
# [Epoch :   29]
# cost = 0.8045442 	 Acc_Test  : 53.0 	 Acc_Train : 68.8
# [Epoch :   30]
# cost = 0.7914888 	 Acc_Test  : 55.0 	 Acc_Train : 68.5
# [Epoch :   31]
# cost = 0.7022242 	 Acc_Test  : 49.0 	 Acc_Train : 75.5
# [Epoch :   32]
# cost = 0.707326 	 Acc_Test  : 55.5 	 Acc_Train : 76.4
# [Epoch :   33]
# cost = 0.6134938 	 Acc_Test  : 57.0 	 Acc_Train : 75.5
# [Epoch :   34]
# cost = 0.750278 	 Acc_Test  : 49.5 	 Acc_Train : 76.1
# [Epoch :   35]
# cost = 0.5769022 	 Acc_Test  : 55.5 	 Acc_Train : 77.8
# [Epoch :   36]
# cost = 0.5301762 	 Acc_Test  : 57.5 	 Acc_Train : 82.1
# [Epoch :   37]
# cost = 0.4648467 	 Acc_Test  : 57.0 	 Acc_Train : 82.5
# [Epoch :   38]
# cost = 0.482565 	 Acc_Test  : 48.5 	 Acc_Train : 82.8
# [Epoch :   39]
# cost = 0.5279088 	 Acc_Test  : 54.0 	 Acc_Train : 83.9
# [Epoch :   40]
# cost = 0.5614619 	 Acc_Test  : 51.5 	 Acc_Train : 80.5
# [Epoch :   41]
# cost = 0.4427715 	 Acc_Test  : 60.5 	 Acc_Train : 86.1
# [Epoch :   42]
# cost = 0.4667498 	 Acc_Test  : 61.5 	 Acc_Train : 85.2
# [Epoch :   43]
# cost = 0.46751 	 Acc_Test  : 55.5 	 Acc_Train : 83.2
# [Epoch :   44]
# cost = 0.4319678 	 Acc_Test  : 55.5 	 Acc_Train : 86.9
# [Epoch :   45]
# cost = 0.4189109 	 Acc_Test  : 47.0 	 Acc_Train : 86.5
# [Epoch :   46]
# cost = 0.4178709 	 Acc_Test  : 57.0 	 Acc_Train : 87.2
# [Epoch :   47]
# cost = 0.3914891 	 Acc_Test  : 53.5 	 Acc_Train : 87.1
# [Epoch :   48]
# cost = 0.3442596 	 Acc_Test  : 55.5 	 Acc_Train : 90.6
# [Epoch :   49]
# cost = 0.3130196 	 Acc_Test  : 57.5 	 Acc_Train : 89.9
# [Epoch :   50]
# cost = 0.3652609 	 Acc_Test  : 57.5 	 Acc_Train : 87.1
# [Epoch :   51]
# cost = 0.3349512 	 Acc_Test  : 61.0 	 Acc_Train : 93.4
# [Epoch :   52]
# cost = 0.2429566 	 Acc_Test  : 60.0 	 Acc_Train : 94.1
# [Epoch :   53]
# cost = 0.2895251 	 Acc_Test  : 56.0 	 Acc_Train : 92.0
# [Epoch :   54]
# cost = 0.2392249 	 Acc_Test  : 60.0 	 Acc_Train : 92.0
# [Epoch :   55]
# cost = 0.2498064 	 Acc_Test  : 51.5 	 Acc_Train : 93.0
# [Epoch :   56]
# cost = 0.2381361 	 Acc_Test  : 56.5 	 Acc_Train : 93.1
# [Epoch :   57]
# cost = 0.2218563 	 Acc_Test  : 57.0 	 Acc_Train : 93.5
# [Epoch :   58]
# cost = 0.2746613 	 Acc_Test  : 56.0 	 Acc_Train : 92.9
# [Epoch :   59]
# cost = 0.2136422 	 Acc_Test  : 56.5 	 Acc_Train : 93.0
# [Epoch :   60]
# cost = 0.2104038 	 Acc_Test  : 58.5 	 Acc_Train : 96.1
# [Epoch :   61]
# cost = 0.2008758 	 Acc_Test  : 60.5 	 Acc_Train : 95.5
# [Epoch :   62]
# cost = 0.1871002 	 Acc_Test  : 54.0 	 Acc_Train : 96.1
# [Epoch :   63]
# cost = 0.1592595 	 Acc_Test  : 60.0 	 Acc_Train : 97.2
# [Epoch :   64]
# cost = 0.1803093 	 Acc_Test  : 57.0 	 Acc_Train : 96.5
# [Epoch :   65]
# cost = 0.1840132 	 Acc_Test  : 59.5 	 Acc_Train : 96.9
# [Epoch :   66]
# cost = 0.1692004 	 Acc_Test  : 61.0 	 Acc_Train : 97.5
# [Epoch :   67]
# cost = 0.1368453 	 Acc_Test  : 60.5 	 Acc_Train : 94.6
# [Epoch :   68]
# cost = 0.1409198 	 Acc_Test  : 54.0 	 Acc_Train : 97.2
# [Epoch :   69]
# cost = 0.2092018 	 Acc_Test  : 60.5 	 Acc_Train : 96.6
# [Epoch :   70]
# cost = 0.1642562 	 Acc_Test  : 60.0 	 Acc_Train : 96.8
# [Epoch :   71]
# cost = 0.1503324 	 Acc_Test  : 61.0 	 Acc_Train : 96.6
# [Epoch :   72]
# cost = 0.1417384 	 Acc_Test  : 60.5 	 Acc_Train : 96.0
# [Epoch :   73]
# cost = 0.1577304 	 Acc_Test  : 56.5 	 Acc_Train : 95.8
# [Epoch :   74]
# cost = 0.1972635 	 Acc_Test  : 58.0 	 Acc_Train : 96.8
# [Epoch :   75]
# cost = 0.162851 	 Acc_Test  : 58.5 	 Acc_Train : 97.8
# [Epoch :   76]
# cost = 0.1415129 	 Acc_Test  : 58.5 	 Acc_Train : 97.1
# [Epoch :   77]
# cost = 0.1544196 	 Acc_Test  : 58.0 	 Acc_Train : 98.1
# [Epoch :   78]
# cost = 0.1437117 	 Acc_Test  : 60.0 	 Acc_Train : 97.9
# [Epoch :   79]
# cost = 0.1401931 	 Acc_Test  : 57.5 	 Acc_Train : 97.1
# [Epoch :   80]
# cost = 0.1362821 	 Acc_Test  : 59.0 	 Acc_Train : 97.2
# [Epoch :   81]
# cost = 0.1202645 	 Acc_Test  : 56.5 	 Acc_Train : 97.9
# [Epoch :   82]
# cost = 0.124737 	 Acc_Test  : 60.5 	 Acc_Train : 97.0
# [Epoch :   83]
# cost = 0.1333231 	 Acc_Test  : 59.5 	 Acc_Train : 98.2
# [Epoch :   84]
# cost = 0.1419533 	 Acc_Test  : 57.0 	 Acc_Train : 98.6
# [Epoch :   85]
# cost = 0.1213021 	 Acc_Test  : 57.5 	 Acc_Train : 97.2
# [Epoch :   86]
# cost = 0.1178555 	 Acc_Test  : 58.0 	 Acc_Train : 97.1
# [Epoch :   87]
# cost = 0.1251971 	 Acc_Test  : 60.5 	 Acc_Train : 98.2
# [Epoch :   88]
# cost = 0.1493396 	 Acc_Test  : 57.5 	 Acc_Train : 97.0
# [Epoch :   89]
# cost = 0.1284972 	 Acc_Test  : 56.5 	 Acc_Train : 98.4
# [Epoch :   90]
# cost = 0.1227319 	 Acc_Test  : 55.5 	 Acc_Train : 97.4
# [Epoch :   91]
# cost = 0.1359948 	 Acc_Test  : 57.0 	 Acc_Train : 96.0
# [Epoch :   92]
# cost = 0.1404043 	 Acc_Test  : 59.0 	 Acc_Train : 97.9
# [Epoch :   93]
# cost = 0.1563146 	 Acc_Test  : 59.0 	 Acc_Train : 99.1
# [Epoch :   94]
# cost = 0.1082806 	 Acc_Test  : 59.5 	 Acc_Train : 98.5
# [Epoch :   95]
# cost = 0.1583285 	 Acc_Test  : 62.0 	 Acc_Train : 97.2
# [Epoch :   96]
# cost = 0.1072747 	 Acc_Test  : 55.5 	 Acc_Train : 96.8
# [Epoch :   97]
# cost = 0.121383 	 Acc_Test  : 64.5 	 Acc_Train : 98.5
# [Epoch :   98]
# cost = 0.09850887 	 Acc_Test  : 66.5 	 Acc_Train : 98.5
# [Epoch :   99]
# cost = 0.1081515 	 Acc_Test  : 58.5 	 Acc_Train : 98.0
# [Epoch :  100]
# cost = 0.1725072 	 Acc_Test  : 63.5 	 Acc_Train : 98.1
# Learning finished

# %%
correct = 0
total = 0

with torch.no_grad():
    for data in test_loader:
        images, labels = data
        images = images.to(device)
        labels = labels.to(device)
        outputs = net(images)
        
        _, predicted = torch.max(outputs.data, 1)
        
        total += labels.size(0)
        
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the test images: %d %%' % (
    100 * correct / total))
# Out:
# Accuracy of the network on the test images: 61 %

# %%
correct = 0
total = 0

with torch.no_grad():
    for data in train_loader:
        images, labels = data
        images = images.to(device)
        labels = labels.to(device)
        outputs = net(images)
        
        _, predicted = torch.max(outputs.data, 1)
        
        total += labels.size(0)
        
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the train images: %d %%' % (
    100 * correct / total))
# Out:
# Accuracy of the network on the train images: 97 %
